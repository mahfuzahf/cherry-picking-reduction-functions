# %%
# Imports
from utils import *
from math import e
import pickle

# Constants
N = 2 ** 16
alpha = 0.95
p = 1 - e **(-2)

# run optimisation
kis, m_0, final_cost, m_values = optimise_kj(N, p, alpha, 5, 1)

# store kis in a pickle file
with open("N16_alpha_0.95_kis.pkl", "wb") as f:
        pickle.dump(kis, f)
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -2264.0897222533777
#             Iterations: 19
#             Function evaluations: 1550
#             Gradient evaluations: 19

# %%
# plot kis
import matplotlib.pyplot as plt
plt.plot(kis)
plt.xlabel("j")
plt.ylabel("k_j")
plt.title("Optimal k_j values for N=2^16, alpha=0.62")
plt.grid()
