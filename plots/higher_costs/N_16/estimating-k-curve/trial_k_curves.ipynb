# %% [markdown]
# # Trying a bunc of k curves and tryna find which one is best

# %%
import pickle

with open("data/cherry_N_16_different_alpha_0.5_0.95_optimisation_results.pkl", "rb") as f:
    results = pickle.load(f)

kjs, _, _, _ = results[-1]

for item in kjs:
    print(item)

with open("data/N_16_alpha_0.95_cost_5_t_80_optimised_kis.pkl", "wb") as f:
    pickle.dump(kjs, f)
# Out:
# 1.0
# 698.3480941740265
# 821.1206392828288
# 931.6997141161263
# 1033.0085252640501
# 1126.2317266219663
# 1213.6095709379747
# 1295.3702498744817
# 1372.543088512778
# 1445.3838512825978
# 1514.7997528743003
# 1580.586191411633
# 1643.8197050979925
# 1704.3204110848462
# 1762.4857095029888
# 1818.4047203627094
# 1872.110565250846
# 1924.0852777565228
# 1974.1876715709718
# 2022.690068663222
# 2069.7778901358924
# 2115.485972079666
# 2159.621955509242
# 2203.0991997783403
# 2244.696745863757
# 2284.8552823840405
# 2325.182141927507
# 2363.7310944726864
# 2401.4655502630335
# 2438.664041974957
# 2474.4144895820273
# 2510.2257754299535
# 2544.5602919498215
# 2578.56922909382
# 2611.7210977631794
# 2644.28357627855
# 2675.7887894307014
# 2707.3555904760606
# 2738.2191510986568
# 2768.2098551038516
# 2797.837967998105
# 2826.886558008435
# 2855.6694112127466
# 2883.491985432148
# 2911.480145320377
# 2939.100477351159
# 2965.770456629982
# 2992.591446995387
# 3018.459736627217
# ...
